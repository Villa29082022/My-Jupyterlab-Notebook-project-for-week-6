# %% [markdown]
# # My Jupyterlab Notebook project for week 6

# %% [markdown]
# ## Introduction
# This notebook explores various tools and techniques in data science, demonstrating practical applications through simple examples.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Scikit-Learn
# - TensorFlow
# - PyTorch

# %% [markdown]
# ## Data Science Tools
#
# | Tool | Usage |
# |-------------|-----|
# | Jupyter | Development of notebooks for data analysis |
# | Colab | Cloud Notebooks with Free GPU Resources |
# | RStudio | Development environment for R |
# | Tableau | Data visualization |

# %% [markdown]
# ## Arithmetic Expressions
# Arithmetic expressions are constructs in a programming language that produce a numerical value. Common examples include adding `+`, subtracting `-`, multiplying `*`, and dividing `/`.

# %%
# Multiply and add numbers
result = (10 * 5) + (2 * 3)
result
# Out:
# 56

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %%
# Project Objectives
objectives = ["Understand the main data science tools",
             "Apply data analysis techniques",
             "Demonstrate the use of Python libraries"]
objectives
# Out:
# ['Understand the main data science tools',
#  'Apply data analysis techniques',
#  'Demonstrate the use of Python libraries']

# %% [markdown]
# ## Author
# Alexandro Daniel Villarruel Mandujano
